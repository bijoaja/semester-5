# %%
#=======================================================================#
#Latihan 1: Membaca Data dari File
#=======================================================================#

# Contoh kode dibawah menggunakan dataset diamonds 

#1.	Buka jupyter notebook dan import library/pustaka pandas and seaborn:
import pandas as pd 
import seaborn as sns

#2.	Tentukan URL dari datasetnya
diamonds_url = "https://raw.githubusercontent.com/TrainingByPackt/Interactive-Data-Visualization-with-Python/master/datasets/diamonds.csv"
 
#3.	Baca File dari URL dan ditampung menggunakan "DataFrame (pandas)":
diamonds_df = pd.read_csv(diamonds_url)
# Sebagai alternatif karena dataset sudah tersedia di Library "seaborn", maka bisa membacanya juga melalui kode dibawah:
diamonds_df = sns.load_dataset('diamonds')
# Jika yang dibaca hanya kolom-kolom tertentu gunakan kode dibawah:
diamonds_df_specific_cols = pd.read_csv(diamonds_url,usecols=['carat','cut','color','clarity'])


#=======================================================================#
#Latihan 2: Mengobservasi dan Mendeskripsikan Data
#=======================================================================#

#Gunakan dataset diamonds:
#1.	import library pandas dan seaborn
import pandas as pd 
import seaborn as sns
#2.	Tentukan URL datasetnya:
diamonds_url = "https://raw.githubusercontent.com/TrainingByPackt/Interactive-Data-Visualization-with-Python/master/datasets/diamonds.csv"
 
#3.	Baca File dari URL dan ditampung menggunakan "DataFrame (pandas)":
diamonds_df = pd.read_csv(diamonds_url)

#4.	Mendapatkan sebagian data menggunakan fungsi "head"
diamonds_df.head()
#Data berisi fitur-fitur berbeda dari "diamonds", misal carat, cut quality, color, dan price sebagai kolom-kolomnya.
#cut,clarity, dan color adalah variabel "categorical" sedangkan x,y,z,depth,table, dan price adalah variabel "continous"

#5.	Hitung jumlah baris dan kolom di DataFrame menggunakan fungsi "shape"
diamonds_df.shape

#6.	Ringkas kolom-kolomnya menggunakan describe() untuk mendapatkan distribusi dari variabel-variabelnya,
#   misal mean, median, min, max, and the different quartiles:
diamonds_df.describe()

#   untuk variabel categorical perlu menggunakan parameter include=object
diamonds_df.describe(include=object)


#7.	Memperoleh informasi dari dataset, gunakan method info():
diamonds_df.info()
#hasilnya menunjukkan tipe data dari tiap-tiap kolom (float64, object, int64), ukuran memori, dan jumlah barisnya
 

#Memilih kolom dari sebuah DataFrame
diamonds_low_df = diamonds_df.loc[diamonds_df['cut']=='Ideal'] 
diamonds_low_df.head()

#=======================================================================#
#Latihan 3: Menambah kolom baru ke DataFrame
#=======================================================================#

#1.	import library pandas dan seaborn:
import pandas as pd 
import seaborn as sns

#2.	Tentukan URL dataset:
diamonds_url = "https://raw.githubusercontent.com/TrainingByPackt/Interactive-Data-Visualization-with-Python/master/datasets/diamonds.csv"

#3.	Baca File dari URL dan tampung menggunakan DataFrame:
diamonds_df = pd.read_csv(diamonds_url)

#4.	Tambahkan kolom "price_per_carat" ke DataFrame:
diamonds_df['price_per_carat'] = diamonds_df['price']/diamonds_df['carat']

#5.	Panggil fungsi head() untuk melihat hasilnya:
diamonds_df.head()
#Contoh sederhana penambahan kolom
 
#6.	Gunakan fungsi np.where dari package "numpy" Python:
import numpy as np
diamonds_df['price_per_carat_is_high'] = np.where(diamonds_df['price_per_carat']>3500,1,0)
diamonds_df.head()
# Contoh penambahan kolom "additional"

#=======================================================================#
#Latihan 4: Mengaplikasikan fungsi-fungsi pada kolom DataFrame
#=======================================================================#

#1.	import pandas dan seaborn:
import pandas as pd 
import seaborn as sns

#2.	Tentukan URL dataset:
diamonds_url = "https://raw.githubusercontent.com/TrainingByPackt/Interactive-Data-Visualization-with-Python/master/datasets/diamonds.csv"

#3.	Baca File dari URL dan tampung menggunakan DataFrame:
diamonds_df = pd.read_csv(diamonds_url)

#4.	Add a price_per_carat column to the DataFrame:
diamonds_df['price_per_carat'] = diamonds_df['price']/diamonds_df['carat']

#5.	Gunakan fungsi "np.where" package "numpy":
import numpy as np
diamonds_df['price_per_carat_is_high'] = np.where(diamonds_df['price_per_carat']>3500,1,0)

#6.	Gunakan/masukkan sebuah fungsi/formula sederhana pada kolom
diamonds_df['price']= diamonds_df['price']*1.3
 
#7.	Import Library "math", lalu gunakan sebuah fungsi (lebih kompleks) untuk membulatkan nilai price dari diamonds
import math 
diamonds_df['rounded_price']=diamonds_df['price'].apply(math.ceil) 
diamonds_df.head()
#Dataset setelah diaplikasikan fungsi sederhana and kompleks

#8.	Contoh Mengaplikasikan fungsi "lambda" pada sebuah kolom
import math 
diamonds_df['rounded_price_to_100multiple']=diamonds_df['price'].apply(lambda x: math.ceil(x/100)*100)
diamonds_df.head()
#Dataset setelah mengaplikasikan fungsi "lambda"

#8.	Gunakan "user-defined" function untuk membulatkan price 
import math

def get_100_multiple_ceil(x): 
    y = math.ceil(x/100)*100 
    return y

diamonds_df['rounded_price_to_100multiple']=diamonds_df['price'].apply(get_100_multiple_ceil)
diamonds_df.head()

#========================================================================#
#Latihan 5: Mengaplikasikan fungsi pada banyak kolom
#========================================================================#

#1.	Import modul-modul yang dibutuhkan
import seaborn as sns 
import pandas as pd

#2. Import dataset dari seaborn:
diamonds_df_exercise = sns.load_dataset('diamonds')

#3.	Buat sebuah fungsi untuk menentukan apakah sebuah baris x diperlukan atau tidak
def is_desired(x):
    bool_var = 'yes' if (x['cut']=='Ideal' and x['color']=='D') else 'no'
    return bool_var

#4.	Gunakan fungsi "apply function to add the new column, desired:
diamonds_df_exercise['desired']=diamonds_df_exercise.apply(is_desired, axis=1)
diamonds_df_exercise.head()
#Dataset setelah applying the function pada banyak kolom


#=======================================================================#
#Latihan 6: Deleting Columns from a DataFrame
#=======================================================================#

#1.	Import modul:
import seaborn as sns 
import pandas as pd
 
#2.	Import dataset dari seaborn:
diamonds_df = sns.load_dataset('diamonds')

#3.	Add a price_per_carat column to the DataFrame:
diamonds_df['price_per_carat'] = diamonds_df['price']/diamonds_df['carat']

#4.	Gunakan fungsi "np.where"
import numpy as np
diamonds_df['price_per_carat_is_high'] = np.where(diamonds_df['price_per_carat']>3500,1,0)

#5.	Aplikasikan sebuah fungsi kompleks untuk membulatkan price
import math 
diamonds_df['rounded_price']=diamonds_df['price'].apply(math.ceil)

#6.	Buat user-defined function:
import math

def get_100_multiple_ceil(x): 
    y = math.ceil(x/100)*100 
    return y

diamonds_df['rounded_price_to_100multiple']=diamonds_df['price'].apply(get_100_multiple_ceil)

#7.	Delete kolom "rounded_price" dan "rounded_price_to_100multiple" menggunakan fungsi "drop":
diamonds_df=diamonds_df.drop(columns=['rounded_price', 'rounded_price_to_100multiple'])
diamonds_df.head()

#=======================================================================#
#Latihan 7: Menulis DataFrame ke sebuah File
#=======================================================================#

#1.	Import modul
import seaborn as sns 
import pandas as pd

#2.	Load diamonds dataset dari seaborn:
diamonds_df = sns.load_dataset('diamonds')
 
#3.	Tulias diamonds dataset ke dalam sebuah file berekstensi ".csv"
diamonds_df.to_csv('diamonds_modified.csv')

#4.	Let's look at the first few rows of the DataFrame:
print(diamonds_df.head())

#5.	Menambahkan sebuah parameter index=False untuk meng-exclude "row numbers":
diamonds_df.to_csv('diamonds_modified.csv', index=False)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53940 entries, 0 to 53939
# Data columns (total 10 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   carat    53940 non-null  float64
#  1   cut      53940 non-null  object
#  2   color    53940 non-null  object
#  3   clarity  53940 non-null  object
#  4   depth    53940 non-null  float64
#  5   table    53940 non-null  float64
#  6   price    53940 non-null  int64
#  7   x        53940 non-null  float64
#  8   y        53940 non-null  float64
#  9   z        53940 non-null  float64
# dtypes: float64(6), int64(1), object(3)
# memory usage: 4.1+ MB
#    carat      cut color clarity  depth  table  price     x     y     z
# 0   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# ...
